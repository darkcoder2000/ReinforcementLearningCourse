# %% [markdown]
# # 1. Import Dependencies

# %%
#Install SWIG https://sourceforge.net/projects/swig/files/swigwin/swigwin-4.0.2/swigwin-4.0.2.zip/download?use_mirror=ixpeering

# %%
# !pip install gym[box2d] pyglet==1.3.2
# Out:
# ^C

# %%
import gym 
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
import os

# %% [markdown]
# # 2. Test Environment

# %%
environment_name = "CarRacing-v0"

# %%
env = gym.make(environment_name)
# Out:
# C:\Users\marti\anaconda3\envs\RL_3h\lib\site-packages\gym\logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# Track generation: 1235..1550 -> 315-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1051..1319 -> 268-tiles track
# C:\Users\marti\anaconda3\envs\RL_3h\lib\site-packages\pyglet\image\codecs\wic.py:289: UserWarning: [WinError -2147417850] Der Threadmodus kann nicht nach dem Einstellen geändert werden
#   warnings.warn(str(err))
# Episode:1 Score:-25.09363295880169
# Track generation: 1048..1315 -> 267-tiles track
# Episode:2 Score:-28.571428571428825
# Track generation: 1167..1463 -> 296-tiles track
# Episode:3 Score:-35.59322033898355
# Track generation: 1059..1328 -> 269-tiles track
# Episode:4 Score:-21.641791044776348
# Track generation: 1215..1523 -> 308-tiles track
# Requirement already satisfied: gym[box2d] in c:\users\marti\anaconda3\envs\rl_3h\lib\site-packages (0.18.3)
# Collecting pyglet==1.3.2
#   Downloading pyglet-1.3.2-py2.py3-none-any.whl (1.0 MB)
# Collecting future
#   Using cached future-0.18.2-py3-none-any.whl
# Requirement already satisfied: numpy>=1.10.4 in c:\users\marti\appdata\roaming\python\python37\site-packages (from gym[box2d]) (1.21.4)
# Collecting Pillow<=8.2.0
#   Using cached Pillow-8.2.0-cp37-cp37m-win_amd64.whl (2.2 MB)
# Requirement already satisfied: scipy in c:\users\marti\anaconda3\envs\rl_3h\lib\site-packages (from gym[box2d]) (1.4.1)
# Collecting gym[box2d]
#   Using cached gym-0.21.0-py3-none-any.whl
# Requirement already satisfied: importlib-metadata>=4.8.1 in c:\users\marti\anaconda3\envs\rl_3h\lib\site-packages (from gym[box2d]) (4.8.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\marti\anaconda3\envs\rl_3h\lib\site-packages (from gym[box2d]) (1.6.0)
#   Downloading gym-0.20.0.tar.gz (1.6 MB)
# Collecting box2d-py==2.3.5
#   Using cached box2d-py-2.3.5.tar.gz (374 kB)
# Collecting gym[box2d]
#   Using cached gym-0.19.0-py3-none-any.whl
#   Using cached gym-0.18.0.tar.gz (1.6 MB)
#   Using cached gym-0.17.3.tar.gz (1.6 MB)
#   Using cached gym-0.17.2-py3-none-any.whl
# Collecting cloudpickle<1.4.0,>=1.2.0
#   Using cached cloudpickle-1.3.0-py2.py3-none-any.whl (26 kB)
# Collecting gym[box2d]
#   Downloading gym-0.17.1.tar.gz (1.6 MB)
# Requirement already satisfied: six in c:\users\marti\anaconda3\envs\rl_3h\lib\site-packages (from gym[box2d]) (1.16.0)
#   Downloading gym-0.17.0.tar.gz (1.6 MB)
#   Downloading gym-0.16.0.tar.gz (1.6 MB)
#   Downloading gym-0.15.7.tar.gz (1.6 MB)
#   Downloading gym-0.15.6.tar.gz (1.6 MB)
#   Downloading gym-0.15.4.tar.gz (1.6 MB)
# Collecting cloudpickle~=1.2.0
#   Downloading cloudpickle-1.2.2-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: opencv-python in c:\users\marti\appdata\roaming\python\python37\site-packages (from gym[box2d]) (4.5.4.60)
# Requirement already satisfied: box2d-py~=2.3.5 in c:\users\marti\appdata\roaming\python\python37\site-packages (from gym[box2d]) (2.3.8)
# Building wheels for collected packages: gym
#   Building wheel for gym (setup.py): started
#   Building wheel for gym (setup.py): finished with status 'done'
#   Created wheel for gym: filename=gym-0.15.4-py3-none-any.whl size=1648483 sha256=5ddb7541f9fae0c4edb17e88141f7e934ecd8a515e4bf8651e424f360280fad7
#   Stored in directory: c:\users\marti\appdata\local\pip\cache\wheels\27\97\51\3adbfe67f40bce89b8eba2d3b8f42ec1c9f9c1e6305a73510d
# Successfully built gym
# Installing collected packages: future, pyglet, cloudpickle, gym
#   Attempting uninstall: pyglet
#     Found existing installation: pyglet 1.5.15
#     Uninstalling pyglet-1.5.15:
#       Successfully uninstalled pyglet-1.5.15
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 1.6.0
#     Uninstalling cloudpickle-1.6.0:
#       Successfully uninstalled cloudpickle-1.6.0
#   Attempting uninstall: gym
#     Found existing installation: gym 0.18.3
#     Uninstalling gym-0.18.3:
#       Successfully uninstalled gym-0.18.3
# Successfully installed cloudpickle-1.2.2 future-0.18.2 gym-0.15.4 pyglet-1.3.2
# Episode:5 Score:-34.85342019544019
# WARNING: Ignoring invalid distribution -illow (c:\users\marti\anaconda3\envs\rl_3h\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\marti\anaconda3\envs\rl_3h\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\marti\anaconda3\envs\rl_3h\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\marti\anaconda3\envs\rl_3h\lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# stable-baselines3 1.0 requires gym>=0.17, but you have gym 0.15.4 which is incompatible.

# %%
env.close()

# %%
env.action_space.sample()
# Out:
# array([0.11032022, 0.99365383, 0.69554204], dtype=float32)

# %%
env.observation_space.sample()
# Out:
# array([[[198,  58, 239],
#         [218,  91, 230],
#         [213, 225, 247],
#         ...,
#         [238, 252, 138],
#         [215, 205,  59],
#         [ 65, 204, 249]],
#
#        [[122,   3,  33],
#         [178, 209,  14],
#         [ 27, 131,  27],
#         ...,
#         [ 49, 216, 160],
#         [143, 113, 253],
#         [ 75, 149,  53]],
#
#        [[ 76,  59,  27],
#         [  2, 156, 190],
#         [198,  19, 116],
#         ...,
#         [101, 173, 174],
#         [ 40, 152,  59],
#         [ 46,  21, 108]],
#
#        ...,
#
#        [[119, 150, 141],
#         [191,  20, 172],
#         [100, 139, 213],
#         ...,
#         [ 42,  51,  52],
#         [127,  11,  41],
#         [112, 228, 150]],
#
#        [[ 75,  29, 188],
#         [142, 106,  66],
#         [255, 101,  87],
#         ...,
#         [199, 170, 100],
#         [242, 198, 223],
#         [145, 114, 176]],
#
#        [[ 87,  17,  32],
#         [195,  62, 158],
#         [100, 157,  15],
#         ...,
#         [169, 168,  17],
#         [171, 108,  39],
#         [ 67,  52, 255]]], dtype=uint8)

# %% [markdown]
# # 3. Train Model

# %%
log_path = os.path.join('Training', 'Logs')
env = gym.make(environment_name)
env = DummyVecEnv([lambda: env])

# %%
model = PPO("CnnPolicy", env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=100000)
# Out:
# Track generation: 1173..1477 -> 304-tiles track
# Logging to Training\Logs\PPO_2
# Track generation: 1125..1419 -> 294-tiles track
# Track generation: 1175..1473 -> 298-tiles track
# -----------------------------
# | time/              |      |
# |    fps             | 97   |
# |    iterations      | 1    |
# |    time_elapsed    | 21   |
# |    total_timesteps | 2048 |
# -----------------------------
# Track generation: 1191..1493 -> 302-tiles track
# Track generation: 1016..1281 -> 265-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 99          |
# |    iterations           | 2           |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.002556549 |
# |    clip_fraction        | 0.0658      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.25       |
# |    explained_variance   | 0.00457     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.248       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00698    |
# |    std                  | 0.994       |
# |    value_loss           | 0.612       |
# -----------------------------------------
# Track generation: 1033..1304 -> 271-tiles track
# Track generation: 1018..1278 -> 260-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1200..1504 -> 304-tiles track
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 104          |
# |    iterations           | 3            |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0095117185 |
# |    clip_fraction        | 0.109        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.23        |
# |    explained_variance   | 0.168        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.181        |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0126      |
# |    std                  | 0.99         |
# |    value_loss           | 0.506        |
# ------------------------------------------
# Track generation: 1196..1499 -> 303-tiles track
# Track generation: 1213..1523 -> 310-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1131..1418 -> 287-tiles track
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 106          |
# |    iterations           | 4            |
# |    time_elapsed         | 77           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0059312847 |
# |    clip_fraction        | 0.105        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.22        |
# |    explained_variance   | 0.137        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.323        |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0126      |
# |    std                  | 0.985        |
# |    value_loss           | 0.73         |
# ------------------------------------------
# Track generation: 1185..1490 -> 305-tiles track
# Track generation: 1037..1300 -> 263-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 108         |
# |    iterations           | 5           |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.011980366 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.21       |
# |    explained_variance   | 0.14        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0523      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0212     |
# |    std                  | 0.983       |
# |    value_loss           | 0.335       |
# -----------------------------------------
# Track generation: 1176..1474 -> 298-tiles track
# Track generation: 1092..1377 -> 285-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 109         |
# |    iterations           | 6           |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.014536783 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.19       |
# |    explained_variance   | 0.204       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0612      |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0231     |
# |    std                  | 0.974       |
# |    value_loss           | 0.418       |
# -----------------------------------------
# Track generation: 1113..1401 -> 288-tiles track
# Track generation: 1131..1418 -> 287-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 7           |
# |    time_elapsed         | 129         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.024340216 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.17       |
# |    explained_variance   | 0.447       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0337      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0272     |
# |    std                  | 0.969       |
# |    value_loss           | 0.329       |
# -----------------------------------------
# Track generation: 1200..1504 -> 304-tiles track
# Track generation: 1166..1465 -> 299-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1137..1425 -> 288-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 8           |
# |    time_elapsed         | 147         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.014511084 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.15       |
# |    explained_variance   | 0.582       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.17        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0215     |
# |    std                  | 0.959       |
# |    value_loss           | 0.424       |
# -----------------------------------------
# Track generation: 1148..1439 -> 291-tiles track
# Track generation: 1314..1647 -> 333-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 112        |
# |    iterations           | 9          |
# |    time_elapsed         | 164        |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.03933648 |
# |    clip_fraction        | 0.24       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.1       |
# |    explained_variance   | 0.576      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00821    |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.0396    |
# |    std                  | 0.941      |
# |    value_loss           | 0.269      |
# ----------------------------------------
# Track generation: 1055..1323 -> 268-tiles track
# Track generation: 1092..1369 -> 277-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 10          |
# |    time_elapsed         | 181         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.046689793 |
# |    clip_fraction        | 0.291       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.07       |
# |    explained_variance   | 0.463       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0199      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0363     |
# |    std                  | 0.937       |
# |    value_loss           | 0.265       |
# -----------------------------------------
# Track generation: 1140..1428 -> 288-tiles track
# Track generation: 1132..1419 -> 287-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 113        |
# |    iterations           | 11         |
# |    time_elapsed         | 199        |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.05198845 |
# |    clip_fraction        | 0.299      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.05      |
# |    explained_variance   | 0.28       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0158    |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.0381    |
# |    std                  | 0.926      |
# |    value_loss           | 0.305      |
# ----------------------------------------
# Track generation: 976..1223 -> 247-tiles track
# Track generation: 1135..1423 -> 288-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 12          |
# |    time_elapsed         | 216         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.063910484 |
# |    clip_fraction        | 0.277       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4          |
# |    explained_variance   | 0.475       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0201     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0394     |
# |    std                  | 0.914       |
# |    value_loss           | 0.179       |
# -----------------------------------------
# Track generation: 968..1214 -> 246-tiles track
# Track generation: 1405..1760 -> 355-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 13          |
# |    time_elapsed         | 235         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.050107814 |
# |    clip_fraction        | 0.296       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.95       |
# |    explained_variance   | 0.577       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0426     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0361     |
# |    std                  | 0.893       |
# |    value_loss           | 0.163       |
# -----------------------------------------
# Track generation: 1187..1488 -> 301-tiles track
# Track generation: 1115..1398 -> 283-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 14          |
# |    time_elapsed         | 252         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.048393868 |
# |    clip_fraction        | 0.284       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.9        |
# |    explained_variance   | 0.648       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0251     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0344     |
# |    std                  | 0.886       |
# |    value_loss           | 0.204       |
# -----------------------------------------
# Track generation: 1137..1425 -> 288-tiles track
# Track generation: 1078..1356 -> 278-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 112        |
# |    iterations           | 15         |
# |    time_elapsed         | 272        |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.06527005 |
# |    clip_fraction        | 0.333      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.88      |
# |    explained_variance   | 0.77       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00643   |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.0324    |
# |    std                  | 0.878      |
# |    value_loss           | 0.197      |
# ----------------------------------------
# Track generation: 1067..1338 -> 271-tiles track
# Track generation: 910..1144 -> 234-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1115..1398 -> 283-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 111        |
# |    iterations           | 16         |
# |    time_elapsed         | 293        |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.04679424 |
# |    clip_fraction        | 0.289      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.84      |
# |    explained_variance   | 0.714      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.011      |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.0321    |
# |    std                  | 0.867      |
# |    value_loss           | 0.335      |
# ----------------------------------------
# Track generation: 1128..1414 -> 286-tiles track
# Track generation: 1052..1319 -> 267-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 17          |
# |    time_elapsed         | 314         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.036129598 |
# |    clip_fraction        | 0.295       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.8        |
# |    explained_variance   | 0.856       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0442     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0432     |
# |    std                  | 0.856       |
# |    value_loss           | 0.174       |
# -----------------------------------------
# Track generation: 1056..1324 -> 268-tiles track
# Track generation: 1300..1627 -> 327-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 18          |
# |    time_elapsed         | 331         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.034693975 |
# |    clip_fraction        | 0.317       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.77       |
# |    explained_variance   | 0.706       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0198     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0383     |
# |    std                  | 0.844       |
# |    value_loss           | 0.349       |
# -----------------------------------------
# Track generation: 1132..1419 -> 287-tiles track
# Track generation: 1099..1382 -> 283-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 110        |
# |    iterations           | 19         |
# |    time_elapsed         | 350        |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.06373811 |
# |    clip_fraction        | 0.34       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.73      |
# |    explained_variance   | 0.722      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0154    |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.0425    |
# |    std                  | 0.833      |
# |    value_loss           | 0.426      |
# ----------------------------------------
# Track generation: 1054..1321 -> 267-tiles track
# Track generation: 1076..1349 -> 273-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 20          |
# |    time_elapsed         | 369         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.076626986 |
# |    clip_fraction        | 0.364       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.69       |
# |    explained_variance   | 0.719       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0321     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0507     |
# |    std                  | 0.823       |
# |    value_loss           | 0.407       |
# -----------------------------------------
# Track generation: 1141..1430 -> 289-tiles track
# Track generation: 1005..1268 -> 263-tiles track
# Track generation: 1091..1367 -> 276-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 21          |
# |    time_elapsed         | 387         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.058661617 |
# |    clip_fraction        | 0.365       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.66       |
# |    explained_variance   | 0.717       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.031       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0427     |
# |    std                  | 0.818       |
# |    value_loss           | 0.466       |
# -----------------------------------------
# Track generation: 1119..1402 -> 283-tiles track
# Track generation: 1164..1459 -> 295-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 22          |
# |    time_elapsed         | 405         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.071415655 |
# |    clip_fraction        | 0.35        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.64       |
# |    explained_variance   | 0.303       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0103     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0504     |
# |    std                  | 0.813       |
# |    value_loss           | 0.591       |
# -----------------------------------------
# Track generation: 1319..1653 -> 334-tiles track
# Track generation: 1072..1344 -> 272-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 23          |
# |    time_elapsed         | 423         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.084598556 |
# |    clip_fraction        | 0.44        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.6        |
# |    explained_variance   | 0.498       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00911    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0497     |
# |    std                  | 0.8         |
# |    value_loss           | 0.738       |
# -----------------------------------------
# Track generation: 975..1223 -> 248-tiles track
# Track generation: 1168..1464 -> 296-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 111        |
# |    iterations           | 24         |
# |    time_elapsed         | 440        |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.08719413 |
# |    clip_fraction        | 0.416      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.56      |
# |    explained_variance   | 0.712      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0514    |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.049     |
# |    std                  | 0.789      |
# |    value_loss           | 0.336      |
# ----------------------------------------
# Track generation: 963..1208 -> 245-tiles track
# Track generation: 1196..1499 -> 303-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 111        |
# |    iterations           | 25         |
# |    time_elapsed         | 457        |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.07749905 |
# |    clip_fraction        | 0.408      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.52      |
# |    explained_variance   | 0.275      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0146     |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.0448    |
# |    std                  | 0.782      |
# |    value_loss           | 0.789      |
# ----------------------------------------
# Track generation: 1111..1393 -> 282-tiles track
# Track generation: 1201..1505 -> 304-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 26          |
# |    time_elapsed         | 474         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.048676595 |
# |    clip_fraction        | 0.374       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.49       |
# |    explained_variance   | 0.573       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0785      |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0463     |
# |    std                  | 0.773       |
# |    value_loss           | 0.9         |
# -----------------------------------------
# Track generation: 1048..1314 -> 266-tiles track
# Track generation: 1187..1488 -> 301-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 112        |
# |    iterations           | 27         |
# |    time_elapsed         | 491        |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.09499876 |
# |    clip_fraction        | 0.408      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.45      |
# |    explained_variance   | 0.819      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0589     |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.0515    |
# |    std                  | 0.759      |
# |    value_loss           | 0.63       |
# ----------------------------------------
# Track generation: 1103..1383 -> 280-tiles track
# Track generation: 1186..1486 -> 300-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 112        |
# |    iterations           | 28         |
# |    time_elapsed         | 509        |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.11261358 |
# |    clip_fraction        | 0.467      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.4       |
# |    explained_variance   | 0.835      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00592    |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.0442    |
# |    std                  | 0.753      |
# |    value_loss           | 0.733      |
# ----------------------------------------
# Track generation: 1102..1382 -> 280-tiles track
# Track generation: 1136..1424 -> 288-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 29          |
# |    time_elapsed         | 527         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.111265555 |
# |    clip_fraction        | 0.461       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.38       |
# |    explained_variance   | 0.86        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0396      |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0456     |
# |    std                  | 0.746       |
# |    value_loss           | 0.603       |
# -----------------------------------------
# Track generation: 1113..1395 -> 282-tiles track
# Track generation: 1119..1403 -> 284-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 112        |
# |    iterations           | 30         |
# |    time_elapsed         | 546        |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.06981863 |
# |    clip_fraction        | 0.413      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.34      |
# |    explained_variance   | 0.734      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.153      |
# |    n_updates            | 290        |
# |    policy_gradient_loss | -0.041     |
# |    std                  | 0.737      |
# |    value_loss           | 1.21       |
# ----------------------------------------
# Track generation: 1188..1489 -> 301-tiles track
# Track generation: 1111..1399 -> 288-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 31          |
# |    time_elapsed         | 564         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.050340664 |
# |    clip_fraction        | 0.392       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.3        |
# |    explained_variance   | 0.675       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.155       |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0374     |
# |    std                  | 0.729       |
# |    value_loss           | 1.47        |
# -----------------------------------------
# Track generation: 1292..1619 -> 327-tiles track
# Track generation: 1015..1277 -> 262-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 112        |
# |    iterations           | 32         |
# |    time_elapsed         | 582        |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.07417498 |
# |    clip_fraction        | 0.43       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.27      |
# |    explained_variance   | 0.511      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.066      |
# |    n_updates            | 310        |
# |    policy_gradient_loss | -0.0312    |
# |    std                  | 0.722      |
# |    value_loss           | 1.56       |
# ----------------------------------------
# Track generation: 1163..1458 -> 295-tiles track
# Track generation: 1099..1385 -> 286-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 33          |
# |    time_elapsed         | 600         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.040811256 |
# |    clip_fraction        | 0.394       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.25       |
# |    explained_variance   | 0.411       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0881      |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0341     |
# |    std                  | 0.718       |
# |    value_loss           | 2           |
# -----------------------------------------
# Track generation: 1105..1393 -> 288-tiles track
# Track generation: 1136..1423 -> 287-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 34          |
# |    time_elapsed         | 618         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.103571266 |
# |    clip_fraction        | 0.487       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.23       |
# |    explained_variance   | 0.699       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0427      |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.041      |
# |    std                  | 0.711       |
# |    value_loss           | 1.28        |
# -----------------------------------------
# Track generation: 1013..1276 -> 263-tiles track
# Track generation: 1177..1475 -> 298-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 112        |
# |    iterations           | 35         |
# |    time_elapsed         | 636        |
# |    total_timesteps      | 71680      |
# | train/                  |            |
# |    approx_kl            | 0.04307559 |
# |    clip_fraction        | 0.414      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.21      |
# |    explained_variance   | 0.838      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00759    |
# |    n_updates            | 340        |
# |    policy_gradient_loss | -0.0323    |
# |    std                  | 0.708      |
# |    value_loss           | 1.16       |
# ----------------------------------------
# Track generation: 1095..1373 -> 278-tiles track
# Track generation: 1139..1436 -> 297-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 112        |
# |    iterations           | 36         |
# |    time_elapsed         | 654        |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.08378164 |
# |    clip_fraction        | 0.463      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.19      |
# |    explained_variance   | 0.579      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.172      |
# |    n_updates            | 350        |
# |    policy_gradient_loss | -0.0419    |
# |    std                  | 0.704      |
# |    value_loss           | 2.98       |
# ----------------------------------------
# Track generation: 1114..1397 -> 283-tiles track
# Track generation: 1059..1328 -> 269-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 37          |
# |    time_elapsed         | 672         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.052842416 |
# |    clip_fraction        | 0.417       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.18       |
# |    explained_variance   | 0.735       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.549       |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0203     |
# |    std                  | 0.702       |
# |    value_loss           | 2.36        |
# -----------------------------------------
# Track generation: 1364..1709 -> 345-tiles track
# Track generation: 1015..1272 -> 257-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 112        |
# |    iterations           | 38         |
# |    time_elapsed         | 690        |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.09034437 |
# |    clip_fraction        | 0.468      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.16      |
# |    explained_variance   | 0.639      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.357      |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.0286    |
# |    std                  | 0.699      |
# |    value_loss           | 3.62       |
# ----------------------------------------
# Track generation: 1113..1396 -> 283-tiles track
# Track generation: 1145..1440 -> 295-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1168..1464 -> 296-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 112        |
# |    iterations           | 39         |
# |    time_elapsed         | 709        |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.09845266 |
# |    clip_fraction        | 0.446      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.14      |
# |    explained_variance   | 0.795      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.138      |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.0294    |
# |    std                  | 0.691      |
# |    value_loss           | 2.95       |
# ----------------------------------------
# Track generation: 1069..1340 -> 271-tiles track
# Track generation: 1193..1495 -> 302-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 40          |
# |    time_elapsed         | 727         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.071379684 |
# |    clip_fraction        | 0.437       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.11       |
# |    explained_variance   | 0.76        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.336       |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0244     |
# |    std                  | 0.688       |
# |    value_loss           | 3.53        |
# -----------------------------------------
# Track generation: 1057..1330 -> 273-tiles track
# Track generation: 1189..1490 -> 301-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 112        |
# |    iterations           | 41         |
# |    time_elapsed         | 745        |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.18870112 |
# |    clip_fraction        | 0.519      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.1       |
# |    explained_variance   | 0.812      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.233      |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.0256    |
# |    std                  | 0.683      |
# |    value_loss           | 3.6        |
# ----------------------------------------
# Track generation: 1256..1574 -> 318-tiles track
# Track generation: 1188..1494 -> 306-tiles track
# Track generation: 1206..1512 -> 306-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 112        |
# |    iterations           | 42         |
# |    time_elapsed         | 763        |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.15499687 |
# |    clip_fraction        | 0.486      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.07      |
# |    explained_variance   | 0.824      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.44       |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.0274    |
# |    std                  | 0.675      |
# |    value_loss           | 2.96       |
# ----------------------------------------
# Track generation: 1241..1558 -> 317-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1024..1284 -> 260-tiles track
# Track generation: 1119..1403 -> 284-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 43          |
# |    time_elapsed         | 781         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.092669785 |
# |    clip_fraction        | 0.483       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.04       |
# |    explained_variance   | 0.642       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.421       |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0039     |
# |    std                  | 0.672       |
# |    value_loss           | 4.88        |
# -----------------------------------------
# Track generation: 1068..1339 -> 271-tiles track
# Track generation: 1178..1476 -> 298-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 112       |
# |    iterations           | 44        |
# |    time_elapsed         | 799       |
# |    total_timesteps      | 90112     |
# | train/                  |           |
# |    approx_kl            | 0.0801266 |
# |    clip_fraction        | 0.466     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.03     |
# |    explained_variance   | 0.784     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.394     |
# |    n_updates            | 430       |
# |    policy_gradient_loss | -0.00534  |
# |    std                  | 0.671     |
# |    value_loss           | 6.59      |
# ---------------------------------------
# Track generation: 837..1055 -> 218-tiles track
# Track generation: 1107..1395 -> 288-tiles track
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 112       |
# |    iterations           | 45        |
# |    time_elapsed         | 818       |
# |    total_timesteps      | 92160     |
# | train/                  |           |
# |    approx_kl            | 0.1043203 |
# |    clip_fraction        | 0.488     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.04     |
# |    explained_variance   | 0.573     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.53      |
# |    n_updates            | 440       |
# |    policy_gradient_loss | -0.0104   |
# |    std                  | 0.673     |
# |    value_loss           | 4.76      |
# ---------------------------------------
# Track generation: 1120..1404 -> 284-tiles track
# Track generation: 1092..1369 -> 277-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 112        |
# |    iterations           | 46         |
# |    time_elapsed         | 837        |
# |    total_timesteps      | 94208      |
# | train/                  |            |
# |    approx_kl            | 0.14922112 |
# |    clip_fraction        | 0.522      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.04      |
# |    explained_variance   | 0.809      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.342      |
# |    n_updates            | 450        |
# |    policy_gradient_loss | -0.0238    |
# |    std                  | 0.672      |
# |    value_loss           | 3.84       |
# ----------------------------------------
# Track generation: 1002..1258 -> 256-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1168..1464 -> 296-tiles track
# Track generation: 1299..1628 -> 329-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 47          |
# |    time_elapsed         | 855         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.101248324 |
# |    clip_fraction        | 0.491       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.03       |
# |    explained_variance   | 0.853       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.731       |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0206     |
# |    std                  | 0.67        |
# |    value_loss           | 4.14        |
# -----------------------------------------
# Track generation: 1079..1353 -> 274-tiles track
# Track generation: 1139..1428 -> 289-tiles track
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 112         |
# |    iterations           | 48          |
# |    time_elapsed         | 873         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.097011045 |
# |    clip_fraction        | 0.513       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.01       |
# |    explained_variance   | 0.709       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.663       |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00698    |
# |    std                  | 0.667       |
# |    value_loss           | 5.08        |
# -----------------------------------------
# Track generation: 1159..1453 -> 294-tiles track
# Track generation: 1171..1478 -> 307-tiles track
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 112        |
# |    iterations           | 49         |
# |    time_elapsed         | 891        |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.14572182 |
# |    clip_fraction        | 0.487      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3         |
# |    explained_variance   | 0.83       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.431      |
# |    n_updates            | 480        |
# |    policy_gradient_loss | -0.0109    |
# |    std                  | 0.667      |
# |    value_loss           | 4.66       |
# ----------------------------------------

# %% [markdown]
# # 4. Save Model

# %%
ppo_path = os.path.join('Training', 'Saved Models', 'PPO_Driving_model')

# %%
model.save(ppo_path)

# %%
del model

# %%
ppo_path = os.path.join('Training', 'Saved Models', 'PPO_2m_Driving_model')

# %%
model = PPO.load(ppo_path, env)
# Out:
# Wrapping the env in a VecTransposeImage.

# %% [markdown]
# # 5. Evaluate and Test

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# Track generation: 1064..1334 -> 270-tiles track
# Track generation: 1040..1304 -> 264-tiles track
# Track generation: 1296..1624 -> 328-tiles track
# Track generation: 947..1188 -> 241-tiles track
# Track generation: 1023..1287 -> 264-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1230..1542 -> 312-tiles track
# Track generation: 1020..1279 -> 259-tiles track
# Track generation: 1051..1324 -> 273-tiles track
# Track generation: 1142..1431 -> 289-tiles track
# Track generation: 1063..1333 -> 270-tiles track
# Track generation: 1173..1470 -> 297-tiles track
# Track generation: 1090..1372 -> 282-tiles track
# (748.3796, 121.65658)

# %%
env.close()

# %%
obs = env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    env.render()
# Out:
# Track generation: 1040..1311 -> 271-tiles track
# Track generation: 1120..1412 -> 292-tiles track
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20392/3108987609.py in <module>
#       3     action, _states = model.predict(obs)
#       4     obs, rewards, dones, info = env.step(action)
# ----> 5     env.render()
#
# ~\anaconda3\envs\RL_3h\lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py in render(self, mode)
#      83         """
#      84         if self.num_envs == 1:
# ---> 85             return self.envs[0].render(mode=mode)
#      86         else:
#      87             return super().render(mode=mode)
#
# ~\anaconda3\envs\RL_3h\lib\site-packages\gym\core.py in render(self, mode, **kwargs)
#     238         return self.env.close()
#     239
# --> 240     def seed(self, seed=None):
#     241         return self.env.seed(seed)
#     242
#
# ~\anaconda3\envs\RL_3h\lib\site-packages\gym\envs\box2d\car_racing.py in render(self, mode)
#     465         horiz_ind(20, -10.0*self.car.wheels[0].joint.angle, (0,1,0))
#     466         horiz_ind(30, -0.8*self.car.hull.angularVelocity, (1,0,0))
# --> 467         gl.glEnd()
#     468         self.score_label.text = "%04i" % self.reward
#     469         self.score_label.draw()
#
# ~\anaconda3\envs\RL_3h\lib\site-packages\pyglet\window\win32\__init__.py in flip(self)
#     354     def set_minimum_size(self, width, height):
#     355         self._minimum_size = width, height
# --> 356
#     357     def set_maximum_size(self, width, height):
#     358         self._maximum_size = width, height
#
# KeyboardInterrupt:

# %%
env.close()
