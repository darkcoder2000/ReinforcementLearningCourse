# %%
#https://sourceforge.net/projects/swig/files/swigwin/swigwin-4.0.2/swigwin-4.0.2.zip/download?use_mirror=ixpeering

# %% [markdown]
# # 1. Import Dependencies

# %%
import gym 
from gym import Env
from gym.spaces import Discrete, Box, Dict, Tuple, MultiBinary, MultiDiscrete 
import numpy as np
import random
import os
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# # 2. Types of Spaces

# %%
Discrete(3)

# %%
Box(0,1,shape=(3,3)).sample()

# %%
Box(0,255,shape=(3,3), dtype=int).sample()

# %%
Tuple((Discrete(2), Box(0,100, shape=(1,)))).sample()

# %%
Dict({'height':Discrete(2), "speed":Box(0,100, shape=(1,))}).sample()

# %%
MultiBinary(4).sample()

# %%
MultiDiscrete([5,2,2]).sample()

# %% [markdown]
# # 3. Building an Environment
#  - Build an agent to give us the best shower temperature
#  - Randomly temperature
#  - 37 an 39 degrees

# %%
class ShowerEnv(Env):
    def __init__(self):
        # Actions we can take, down, stay, up
        self.action_space = Discrete(3)
        # Temperature array
        self.observation_space = Box(low=np.array([0]), high=np.array([100]))
        #self.observation_space = Box(low=0, high=100, shape=(1,))
        # Set start temp
        self.state = 38 + random.randint(-3,3)
        # Set shower length
        self.shower_length = 60
        
    def step(self, action):
        # Apply action
        # 0 -1 = -1 temperature
        # 1 -1 = 0 
        # 2 -1 = 1 temperature 
        self.state += action -1 
        # Reduce shower length by 1 second
        self.shower_length -= 1 
        
        # Calculate reward
        if self.state >=37 and self.state <=39: 
            reward =1 
        else: 
            reward = -1 
        
        # Check if shower is done
        if self.shower_length <= 0: 
            done = True
        else:
            done = False
        
        # Apply temperature noise
        #self.state += random.randint(-1,1)
        # Set placeholder for info
        info = {}
        
        # Return step information
        return self.state, reward, done, info

    def render(self):
        # Implement viz
        pass
    
    def reset(self):
        # Reset shower temperature
        self.state = np.array([38 + random.randint(-3,3)]).astype(float)
        # Reset shower time
        self.shower_length = 60 
        return self.state

# %%
env=ShowerEnv()

# %%
print(env.observation_space.sample())
print(env.action_space.sample())
# Out:
# [98.50272]
# 2

# %%
env.reset()
# Out:
# array([35.])

# %%
from stable_baselines3.common.env_checker import check_env

# %%
check_env(env, warn=True)

# %% [markdown]
# # 4. Test Environment

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# Episode:1 Score:-54
# Episode:2 Score:-48
# Episode:3 Score:-54
# Episode:4 Score:-52
# Episode:5 Score:-30

# %%
env.close()

# %% [markdown]
# # 5. Train Model

# %%
log_path = os.path.join('Training', 'Logs')

# %%
model = PPO("MlpPolicy", env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=400000)
# Out:
# Logging to Training\Logs\PPO_3
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | -24.1    |
# | time/              |          |
# |    fps             | 185      |
# |    iterations      | 1        |
# |    time_elapsed    | 11       |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -28.7       |
# | time/                   |             |
# |    fps                  | 258         |
# |    iterations           | 2           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.004493369 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | -0.000107   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34          |
# |    n_updates            | 10          |
# |    policy_gradient_loss | 5.16e-05    |
# |    value_loss           | 55.8        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | -29.8      |
# | time/                   |            |
# |    fps                  | 291        |
# |    iterations           | 3          |
# |    time_elapsed         | 21         |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.00994706 |
# |    clip_fraction        | 0.0386     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.1       |
# |    explained_variance   | 0.00125    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 23.2       |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.00458   |
# |    value_loss           | 58.7       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | -29.7      |
# | time/                   |            |
# |    fps                  | 317        |
# |    iterations           | 4          |
# |    time_elapsed         | 25         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.01119677 |
# |    clip_fraction        | 0.0687     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.08      |
# |    explained_variance   | 0.000193   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 38.7       |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.005     |
# |    value_loss           | 65.8       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -27.3       |
# | time/                   |             |
# |    fps                  | 333         |
# |    iterations           | 5           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.010648767 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | -4.96e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.5        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00917    |
# |    value_loss           | 66.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -26.4       |
# | time/                   |             |
# |    fps                  | 345         |
# |    iterations           | 6           |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.005890209 |
# |    clip_fraction        | 0.0277      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.00232    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.5        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00147    |
# |    value_loss           | 57.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -26.6       |
# | time/                   |             |
# |    fps                  | 354         |
# |    iterations           | 7           |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.006650449 |
# |    clip_fraction        | 0.0193      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | -0.000139   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 39.9        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00137    |
# |    value_loss           | 78.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -28.7        |
# | time/                   |              |
# |    fps                  | 361          |
# |    iterations           | 8            |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0013262633 |
# |    clip_fraction        | 0.0227       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -0.000394    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 27.7         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.000814    |
# |    value_loss           | 69.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -26.6        |
# | time/                   |              |
# |    fps                  | 366          |
# |    iterations           | 9            |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0073838606 |
# |    clip_fraction        | 0.0814       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | -3.14e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 35.5         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00487     |
# |    value_loss           | 67.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -25.4        |
# | time/                   |              |
# |    fps                  | 371          |
# |    iterations           | 10           |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0066554854 |
# |    clip_fraction        | 0.058        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | -2.26e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 34.1         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00556     |
# |    value_loss           | 74.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -20.6       |
# | time/                   |             |
# |    fps                  | 376         |
# |    iterations           | 11          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.015256719 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | -0.00188    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 42.6        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0119     |
# |    value_loss           | 66          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -22.3        |
# | time/                   |              |
# |    fps                  | 380          |
# |    iterations           | 12           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0021356624 |
# |    clip_fraction        | 0.0443       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | -0.000205    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 39.4         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00287     |
# |    value_loss           | 71.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -18.6       |
# | time/                   |             |
# |    fps                  | 382         |
# |    iterations           | 13          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.009809085 |
# |    clip_fraction        | 0.0758      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | -0.00288    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.1        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0033     |
# |    value_loss           | 61.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -16.8        |
# | time/                   |              |
# |    fps                  | 386          |
# |    iterations           | 14           |
# |    time_elapsed         | 74           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0032359716 |
# |    clip_fraction        | 0.0486       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 6.32e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 33.1         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00429     |
# |    value_loss           | 75.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -13.3       |
# | time/                   |             |
# |    fps                  | 388         |
# |    iterations           | 15          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.007234865 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.0143      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26          |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00946    |
# |    value_loss           | 67.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -13.6       |
# | time/                   |             |
# |    fps                  | 391         |
# |    iterations           | 16          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.008467845 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | -0.0476     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.7        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.012      |
# |    value_loss           | 63.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -12.8       |
# | time/                   |             |
# |    fps                  | 393         |
# |    iterations           | 17          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.008379239 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.000473    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.9        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00797    |
# |    value_loss           | 59.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -12.5       |
# | time/                   |             |
# |    fps                  | 395         |
# |    iterations           | 18          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.006045623 |
# |    clip_fraction        | 0.0698      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | -0.00811    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.4        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00205    |
# |    value_loss           | 58.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -10.9       |
# | time/                   |             |
# |    fps                  | 397         |
# |    iterations           | 19          |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.009137317 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.01        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.5        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 59.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -15.1        |
# | time/                   |              |
# |    fps                  | 399          |
# |    iterations           | 20           |
# |    time_elapsed         | 102          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0077272803 |
# |    clip_fraction        | 0.0604       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.0199       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 32           |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00145     |
# |    value_loss           | 65.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | -13.1       |
# | time/                   |             |
# |    fps                  | 401         |
# |    iterations           | 21          |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.013352839 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | -0.0739     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.6        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0151     |
# |    value_loss           | 60.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -12.8        |
# | time/                   |              |
# |    fps                  | 402          |
# |    iterations           | 22           |
# |    time_elapsed         | 111          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0077004507 |
# |    clip_fraction        | 0.121        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1           |
# |    explained_variance   | 0.000436     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 27.3         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.0107      |
# |    value_loss           | 58           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | -3.92        |
# | time/                   |              |
# |    fps                  | 401          |
# |    iterations           | 23           |
# |    time_elapsed         | 117          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0029551685 |
# |    clip_fraction        | 0.142        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | -0.0252      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 30.2         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.0101      |
# |    value_loss           | 64.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 2.16         |
# | time/                   |              |
# |    fps                  | 402          |
# |    iterations           | 24           |
# |    time_elapsed         | 121          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0074322615 |
# |    clip_fraction        | 0.0792       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.00021      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22.3         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00271     |
# |    value_loss           | 55.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 7.92        |
# | time/                   |             |
# |    fps                  | 403         |
# |    iterations           | 25          |
# |    time_elapsed         | 126         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.013240319 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.997      |
# |    explained_variance   | -0.00171    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25          |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.014      |
# |    value_loss           | 53.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 12.1         |
# | time/                   |              |
# |    fps                  | 403          |
# |    iterations           | 26           |
# |    time_elapsed         | 131          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0076540923 |
# |    clip_fraction        | 0.128        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.991       |
# |    explained_variance   | -0.000101    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.5         |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00974     |
# |    value_loss           | 49           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 16.1        |
# | time/                   |             |
# |    fps                  | 404         |
# |    iterations           | 27          |
# |    time_elapsed         | 136         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.015348922 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.97       |
# |    explained_variance   | -0.000345   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.5        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0146     |
# |    value_loss           | 34.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 23.5        |
# | time/                   |             |
# |    fps                  | 404         |
# |    iterations           | 28          |
# |    time_elapsed         | 141         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.009008572 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.971      |
# |    explained_variance   | 0.00226     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.3        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 40.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 28.6        |
# | time/                   |             |
# |    fps                  | 404         |
# |    iterations           | 29          |
# |    time_elapsed         | 146         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.024926186 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.956      |
# |    explained_variance   | 0.000706    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.5        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | 0.00109     |
# |    value_loss           | 40.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 32.7        |
# | time/                   |             |
# |    fps                  | 405         |
# |    iterations           | 30          |
# |    time_elapsed         | 151         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.005085058 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.932      |
# |    explained_variance   | 0.000579    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.4        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00435    |
# |    value_loss           | 49.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 35.1         |
# | time/                   |              |
# |    fps                  | 406          |
# |    iterations           | 31           |
# |    time_elapsed         | 156          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0055869264 |
# |    clip_fraction        | 0.138        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.932       |
# |    explained_variance   | -6.15e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21.2         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | 0.00191      |
# |    value_loss           | 49.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 36.6        |
# | time/                   |             |
# |    fps                  | 407         |
# |    iterations           | 32          |
# |    time_elapsed         | 160         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.006668054 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.931      |
# |    explained_variance   | 7.39e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.9        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | 0.00591     |
# |    value_loss           | 47.7        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 38.8       |
# | time/                   |            |
# |    fps                  | 407        |
# |    iterations           | 33         |
# |    time_elapsed         | 165        |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.00558141 |
# |    clip_fraction        | 0.156      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.922     |
# |    explained_variance   | 7.19e-05   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 33.4       |
# |    n_updates            | 320        |
# |    policy_gradient_loss | 0.00267    |
# |    value_loss           | 57.1       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 40.2        |
# | time/                   |             |
# |    fps                  | 407         |
# |    iterations           | 34          |
# |    time_elapsed         | 170         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.009131467 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.908      |
# |    explained_variance   | 7e-05       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.9        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | 0.00208     |
# |    value_loss           | 64.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 36          |
# | time/                   |             |
# |    fps                  | 407         |
# |    iterations           | 35          |
# |    time_elapsed         | 175         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.022449084 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.908      |
# |    explained_variance   | 1.14e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 44.2        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | 0.00554     |
# |    value_loss           | 72.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 37.8         |
# | time/                   |              |
# |    fps                  | 408          |
# |    iterations           | 36           |
# |    time_elapsed         | 180          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0051156813 |
# |    clip_fraction        | 0.189        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.916       |
# |    explained_variance   | -5.87e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 32.7         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.0118      |
# |    value_loss           | 74           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 38.8        |
# | time/                   |             |
# |    fps                  | 408         |
# |    iterations           | 37          |
# |    time_elapsed         | 185         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.021170419 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.924      |
# |    explained_variance   | 1.17e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.9        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | 0.00514     |
# |    value_loss           | 64.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 37.9        |
# | time/                   |             |
# |    fps                  | 409         |
# |    iterations           | 38          |
# |    time_elapsed         | 190         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.022248017 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.892      |
# |    explained_variance   | -2.26e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.9        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | 0.00657     |
# |    value_loss           | 69.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 34.2        |
# | time/                   |             |
# |    fps                  | 409         |
# |    iterations           | 39          |
# |    time_elapsed         | 195         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.011500141 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.907      |
# |    explained_variance   | -3.11e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37.5        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0107     |
# |    value_loss           | 76.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 34.8        |
# | time/                   |             |
# |    fps                  | 409         |
# |    iterations           | 40          |
# |    time_elapsed         | 200         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.019687416 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.893      |
# |    explained_variance   | -9.55e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28          |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00195    |
# |    value_loss           | 61.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 42.6         |
# | time/                   |              |
# |    fps                  | 409          |
# |    iterations           | 41           |
# |    time_elapsed         | 204          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0072209095 |
# |    clip_fraction        | 0.163        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.865       |
# |    explained_variance   | -1.87e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28.7         |
# |    n_updates            | 400          |
# |    policy_gradient_loss | 0.00149      |
# |    value_loss           | 64.4         |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 60        |
# |    ep_rew_mean          | 47.4      |
# | time/                   |           |
# |    fps                  | 410       |
# |    iterations           | 42        |
# |    time_elapsed         | 209       |
# |    total_timesteps      | 86016     |
# | train/                  |           |
# |    approx_kl            | 0.0381394 |
# |    clip_fraction        | 0.168     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.849    |
# |    explained_variance   | -2.5e-06  |
# |    learning_rate        | 0.0003    |
# |    loss                 | 33.5      |
# |    n_updates            | 410       |
# |    policy_gradient_loss | 0.01      |
# |    value_loss           | 70.5      |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 49          |
# | time/                   |             |
# |    fps                  | 410         |
# |    iterations           | 43          |
# |    time_elapsed         | 214         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.017283188 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.82       |
# |    explained_variance   | 8.94e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.7        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | 0.00682     |
# |    value_loss           | 77.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 50          |
# | time/                   |             |
# |    fps                  | 411         |
# |    iterations           | 44          |
# |    time_elapsed         | 219         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.016170038 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.816      |
# |    explained_variance   | -4.41e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 48.2        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | 0.0118      |
# |    value_loss           | 86.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 51.8         |
# | time/                   |              |
# |    fps                  | 411          |
# |    iterations           | 45           |
# |    time_elapsed         | 223          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0047841556 |
# |    clip_fraction        | 0.181        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.804       |
# |    explained_variance   | -3.81e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 55.2         |
# |    n_updates            | 440          |
# |    policy_gradient_loss | 0.00937      |
# |    value_loss           | 91.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 51.9        |
# | time/                   |             |
# |    fps                  | 412         |
# |    iterations           | 46          |
# |    time_elapsed         | 228         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.033131056 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.798      |
# |    explained_variance   | 4.77e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.2        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | 0.00832     |
# |    value_loss           | 98.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 50.9         |
# | time/                   |              |
# |    fps                  | 412          |
# |    iterations           | 47           |
# |    time_elapsed         | 233          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0062653953 |
# |    clip_fraction        | 0.173        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.784       |
# |    explained_variance   | -1.43e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 42.5         |
# |    n_updates            | 460          |
# |    policy_gradient_loss | 0.0137       |
# |    value_loss           | 98.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 45.3        |
# | time/                   |             |
# |    fps                  | 412         |
# |    iterations           | 48          |
# |    time_elapsed         | 238         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.009656672 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.792      |
# |    explained_variance   | 1.49e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.8        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | 0.00782     |
# |    value_loss           | 93.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 39.4        |
# | time/                   |             |
# |    fps                  | 412         |
# |    iterations           | 49          |
# |    time_elapsed         | 243         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.015922112 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.809      |
# |    explained_variance   | -2.26e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35.3        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | 0.00513     |
# |    value_loss           | 86.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 34.5         |
# | time/                   |              |
# |    fps                  | 412          |
# |    iterations           | 50           |
# |    time_elapsed         | 248          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0078996075 |
# |    clip_fraction        | 0.16         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.785       |
# |    explained_variance   | -1.03e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 49.2         |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00297     |
# |    value_loss           | 79.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 29.8        |
# | time/                   |             |
# |    fps                  | 413         |
# |    iterations           | 51          |
# |    time_elapsed         | 252         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.007508891 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.777      |
# |    explained_variance   | -1.47e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35.2        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00625    |
# |    value_loss           | 77.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 30.5        |
# | time/                   |             |
# |    fps                  | 413         |
# |    iterations           | 52          |
# |    time_elapsed         | 257         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.018011285 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.752      |
# |    explained_variance   | 0.000174    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35          |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 68.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 36.3         |
# | time/                   |              |
# |    fps                  | 413          |
# |    iterations           | 53           |
# |    time_elapsed         | 262          |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0144204525 |
# |    clip_fraction        | 0.177        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.746       |
# |    explained_variance   | 0.000405     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 33.1         |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00379     |
# |    value_loss           | 54.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 44.2        |
# | time/                   |             |
# |    fps                  | 414         |
# |    iterations           | 54          |
# |    time_elapsed         | 267         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.023576304 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.714      |
# |    explained_variance   | 0.000312    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.7        |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -9.44e-05   |
# |    value_loss           | 65.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 40.5        |
# | time/                   |             |
# |    fps                  | 414         |
# |    iterations           | 55          |
# |    time_elapsed         | 271         |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.011532413 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.694      |
# |    explained_variance   | 1.16e-05    |
# ...
# |    value_loss           | 96.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 44.3        |
# | time/                   |             |
# |    fps                  | 422         |
# |    iterations           | 179         |
# |    time_elapsed         | 868         |
# |    total_timesteps      | 366592      |
# | train/                  |             |
# |    approx_kl            | 0.109651655 |
# |    clip_fraction        | 0.095       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.389      |
# |    explained_variance   | 0.0296      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.7        |
# |    n_updates            | 1780        |
# |    policy_gradient_loss | 0.00375     |
# |    value_loss           | 79.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 55          |
# | time/                   |             |
# |    fps                  | 422         |
# |    iterations           | 180         |
# |    time_elapsed         | 873         |
# |    total_timesteps      | 368640      |
# | train/                  |             |
# |    approx_kl            | 0.012065011 |
# |    clip_fraction        | 0.0741      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.35       |
# |    explained_variance   | 0.03        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.5        |
# |    n_updates            | 1790        |
# |    policy_gradient_loss | 0.00711     |
# |    value_loss           | 80.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 56.2        |
# | time/                   |             |
# |    fps                  | 422         |
# |    iterations           | 181         |
# |    time_elapsed         | 877         |
# |    total_timesteps      | 370688      |
# | train/                  |             |
# |    approx_kl            | 0.004061614 |
# |    clip_fraction        | 0.0828      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.305      |
# |    explained_variance   | -0.00393    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 38.6        |
# |    n_updates            | 1800        |
# |    policy_gradient_loss | 0.0136      |
# |    value_loss           | 87.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 48.3        |
# | time/                   |             |
# |    fps                  | 422         |
# |    iterations           | 182         |
# |    time_elapsed         | 882         |
# |    total_timesteps      | 372736      |
# | train/                  |             |
# |    approx_kl            | 0.027289126 |
# |    clip_fraction        | 0.0682      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.269      |
# |    explained_variance   | -0.00494    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 49.4        |
# |    n_updates            | 1810        |
# |    policy_gradient_loss | 0.0113      |
# |    value_loss           | 93.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 45.2        |
# | time/                   |             |
# |    fps                  | 422         |
# |    iterations           | 183         |
# |    time_elapsed         | 887         |
# |    total_timesteps      | 374784      |
# | train/                  |             |
# |    approx_kl            | 0.065245666 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.301      |
# |    explained_variance   | -0.0247     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 100         |
# |    n_updates            | 1820        |
# |    policy_gradient_loss | -0.00229    |
# |    value_loss           | 159         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 46.5       |
# | time/                   |            |
# |    fps                  | 422        |
# |    iterations           | 184        |
# |    time_elapsed         | 891        |
# |    total_timesteps      | 376832     |
# | train/                  |            |
# |    approx_kl            | 0.07712347 |
# |    clip_fraction        | 0.159      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.373     |
# |    explained_variance   | -0.000267  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 53.9       |
# |    n_updates            | 1830       |
# |    policy_gradient_loss | -0.0061    |
# |    value_loss           | 115        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 54          |
# | time/                   |             |
# |    fps                  | 422         |
# |    iterations           | 185         |
# |    time_elapsed         | 896         |
# |    total_timesteps      | 378880      |
# | train/                  |             |
# |    approx_kl            | 0.021893954 |
# |    clip_fraction        | 0.0833      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.363      |
# |    explained_variance   | -1.79e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30          |
# |    n_updates            | 1840        |
# |    policy_gradient_loss | 0.0112      |
# |    value_loss           | 88.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 57.1        |
# | time/                   |             |
# |    fps                  | 422         |
# |    iterations           | 186         |
# |    time_elapsed         | 901         |
# |    total_timesteps      | 380928      |
# | train/                  |             |
# |    approx_kl            | 0.011551826 |
# |    clip_fraction        | 0.0608      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.322      |
# |    explained_variance   | -7.15e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.4        |
# |    n_updates            | 1850        |
# |    policy_gradient_loss | 0.00773     |
# |    value_loss           | 100         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 56.6         |
# | time/                   |              |
# |    fps                  | 422          |
# |    iterations           | 187          |
# |    time_elapsed         | 906          |
# |    total_timesteps      | 382976       |
# | train/                  |              |
# |    approx_kl            | 0.0013625799 |
# |    clip_fraction        | 0.0749       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.353       |
# |    explained_variance   | 8.33e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 35.6         |
# |    n_updates            | 1860         |
# |    policy_gradient_loss | 0.0123       |
# |    value_loss           | 109          |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 60         |
# |    ep_rew_mean          | 55.1       |
# | time/                   |            |
# |    fps                  | 422        |
# |    iterations           | 188        |
# |    time_elapsed         | 910        |
# |    total_timesteps      | 385024     |
# | train/                  |            |
# |    approx_kl            | 0.02815153 |
# |    clip_fraction        | 0.0766     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.348     |
# |    explained_variance   | -0.000428  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 75.8       |
# |    n_updates            | 1870       |
# |    policy_gradient_loss | 0.00787    |
# |    value_loss           | 110        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 51.5        |
# | time/                   |             |
# |    fps                  | 422         |
# |    iterations           | 189         |
# |    time_elapsed         | 915         |
# |    total_timesteps      | 387072      |
# | train/                  |             |
# |    approx_kl            | 0.028578017 |
# |    clip_fraction        | 0.0911      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.376      |
# |    explained_variance   | -0.000285   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 40.6        |
# |    n_updates            | 1880        |
# |    policy_gradient_loss | 0.0135      |
# |    value_loss           | 117         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 47.8        |
# | time/                   |             |
# |    fps                  | 422         |
# |    iterations           | 190         |
# |    time_elapsed         | 920         |
# |    total_timesteps      | 389120      |
# | train/                  |             |
# |    approx_kl            | 0.015545111 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.401      |
# |    explained_variance   | -0.000341   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 53.2        |
# |    n_updates            | 1890        |
# |    policy_gradient_loss | -0.0022     |
# |    value_loss           | 124         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 49          |
# | time/                   |             |
# |    fps                  | 422         |
# |    iterations           | 191         |
# |    time_elapsed         | 925         |
# |    total_timesteps      | 391168      |
# | train/                  |             |
# |    approx_kl            | 0.020364769 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.358      |
# |    explained_variance   | -4.73e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 53.3        |
# |    n_updates            | 1900        |
# |    policy_gradient_loss | 0.0111      |
# |    value_loss           | 117         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 49.7        |
# | time/                   |             |
# |    fps                  | 422         |
# |    iterations           | 192         |
# |    time_elapsed         | 929         |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.007221031 |
# |    clip_fraction        | 0.0708      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.343      |
# |    explained_variance   | 2.09e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 52.3        |
# |    n_updates            | 1910        |
# |    policy_gradient_loss | 0.00836     |
# |    value_loss           | 94.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 51.4        |
# | time/                   |             |
# |    fps                  | 422         |
# |    iterations           | 193         |
# |    time_elapsed         | 934         |
# |    total_timesteps      | 395264      |
# | train/                  |             |
# |    approx_kl            | 0.017427348 |
# |    clip_fraction        | 0.0835      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.372      |
# |    explained_variance   | 6.91e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 44.7        |
# |    n_updates            | 1920        |
# |    policy_gradient_loss | 0.00886     |
# |    value_loss           | 104         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 60           |
# |    ep_rew_mean          | 49.5         |
# | time/                   |              |
# |    fps                  | 423          |
# |    iterations           | 194          |
# |    time_elapsed         | 939          |
# |    total_timesteps      | 397312       |
# | train/                  |              |
# |    approx_kl            | 0.0066345898 |
# |    clip_fraction        | 0.0785       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.365       |
# |    explained_variance   | 5.59e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 53.3         |
# |    n_updates            | 1930         |
# |    policy_gradient_loss | 0.00873      |
# |    value_loss           | 104          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 51.3        |
# | time/                   |             |
# |    fps                  | 423         |
# |    iterations           | 195         |
# |    time_elapsed         | 943         |
# |    total_timesteps      | 399360      |
# | train/                  |             |
# |    approx_kl            | 0.018942107 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.366      |
# |    explained_variance   | 0.000105    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 51.2        |
# |    n_updates            | 1940        |
# |    policy_gradient_loss | 0.0117      |
# |    value_loss           | 106         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 60          |
# |    ep_rew_mean          | 51.1        |
# | time/                   |             |
# |    fps                  | 423         |
# |    iterations           | 196         |
# |    time_elapsed         | 948         |
# |    total_timesteps      | 401408      |
# | train/                  |             |
# |    approx_kl            | 0.030550282 |
# |    clip_fraction        | 0.0797      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.363      |
# |    explained_variance   | 0.000106    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 56          |
# |    n_updates            | 1950        |
# |    policy_gradient_loss | 0.0118      |
# |    value_loss           | 100         |
# -----------------------------------------

# %% [markdown]
# # 6. Save Model

# %%
shower_path = os.path.join('Training','Saved Models','Shower_Model_PPO')
model.save(shower_path)

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# C:\Users\marti\anaconda3\envs\RL_3h\lib\site-packages\stable_baselines3\common\evaluation.py:69: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   UserWarning,
# (12.0, 58.787753826796276)
